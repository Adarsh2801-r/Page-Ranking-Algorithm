# %%
import numpy as np
import pandas as pd
import scipy
from scipy import integrate

# %%
# Returns probability transition matrix
def prob_transition_matrix(adj,alpha):
  N = len(adj)
  empty_rows = list(np.where(~adj.any(axis=1))[0])
  for i in empty_rows:
    for j in range(0,N):
      adj[i][j] = 1/N
  
  prob_matrix = adj/adj.sum(axis=1,keepdims=True)
  prob_matrix = prob_matrix * (1-alpha)
  prob_matrix = prob_matrix + alpha/N 

  return prob_matrix

# %%
# TAKE INPUT WEB-GRAPH
N = int(input("Enter number of nodes : "))
e = int(input("Enter number of edges : "))
adj = np.zeros([N,N])
for i in range(0,e):
  lst = list(map(int,input().split()))
  u = lst[0]
  v = lst[1]
  adj[u,v] = 1

adj
# Out:
# Enter number of nodes : 4
# Enter number of edges : 6
# 0 1
# 1 0
# 1 2
# 2 1
# 2 3
# 3 2
# array([[0., 1., 0., 0.],
#        [1., 0., 1., 0.],
#        [0., 1., 0., 1.],
#        [0., 0., 1., 0.]])

# %% [markdown]
# # **PAGE - RANK IMPLEMENTATION WITH LINEAR ALGEBRA PACKAGE**

# %% [markdown]
# ## 1. Without random teleportation (alpha = 0)

# %%
prob_matrix=prob_transition_matrix(adj,0) 
prob_matrix
# Out:
# array([[0. , 1. , 0. , 0. ],
#        [0.5, 0. , 0.5, 0. ],
#        [0. , 0.5, 0. , 0.5],
#        [0. , 0. , 1. , 0. ]])

# %%
left_eigen_vector = scipy.linalg.eig(prob_matrix,left=True,right=False)[1][:,0]
left_eigen_vector = abs(left_eigen_vector / np.sum(left_eigen_vector))
left_eigen_vector
# Out:
# array([5.17877545e+14, 1.03575509e+15, 1.03575509e+15, 5.17877545e+14])

# %%
print("Web pages according to rank (largest to smallest) : ")
list((-left_eigen_vector).argsort()[:N])
# Out:
# Web pages according to rank (largest to smallest) :
# [2, 1, 3, 0]

# %% [markdown]
# ## 2. With random teleportation (alpha = 0.1)

# %%
prob_matrix=prob_transition_matrix(adj,0.1) 
prob_matrix
# Out:
# array([[0.025, 0.925, 0.025, 0.025],
#        [0.475, 0.025, 0.475, 0.025],
#        [0.025, 0.475, 0.025, 0.475],
#        [0.025, 0.025, 0.925, 0.025]])

# %%
left_eigen_vector = scipy.linalg.eig(prob_matrix,left=True,right=False)[1][:,0]
left_eigen_vector = abs(left_eigen_vector / np.sum(left_eigen_vector))
left_eigen_vector
# Out:
# array([0.17241379, 0.32758621, 0.32758621, 0.17241379])

# %%
print("Web pages according to rank (largest to smallest) : ")
list((-left_eigen_vector).argsort()[:N])
# Out:
# Web pages according to rank (largest to smallest) :
# [2, 1, 0, 3]

# %% [markdown]
# # **PAGE - RANK IMPLEMENTATION WITH POWER ITERATION METHOD**

# %% [markdown]
# ## 1. Without random teleportation (alpha = 0)
# ## 2. With random teleportation (alpha = 0.1)

# %%
# Consider random-surfer starts from state 0
# Initial prob_dist vector : [1,0,0,.......]
x = np.zeros(N)
x[0]=1
P = prob_transition_matrix(adj,0.1)
curr_vec = x
prev_vec = np.ones(N)
cou=0
while True :
  print("x"+str(cou)+":"+str(curr_vec))
  curr_vec = x@P
  if (str(curr_vec) == str(prev_vec)):
    break
  prev_vec = curr_vec
  x = curr_vec
  cou+=1

print("Converged steady state vector : ")
final_prob_vect = curr_vec
final_prob_vect
# Out:
# x0:[1. 0. 0. 0.]
# x1:[0.025 0.925 0.025 0.025]
# x2:[0.44125 0.05875 0.46375 0.03625]
# x3:[0.0514375 0.6308125 0.0840625 0.2336875]
# x4:[0.30886563 0.10912188 0.51918438 0.06282813]
# x5:[0.07410484 0.53661203 0.13065016 0.25863297]
# x6:[0.26647541 0.15048693 0.49924509 0.08379257]
# x7:[0.09271912 0.48948816 0.16813243 0.24966029]
# x8:[0.24526967 0.1841068  0.46996393 0.10065959]
# x9:[0.10784806 0.45722647 0.1984417  0.23648377]
# x10:[0.23075191 0.21136202 0.44358731 0.11429876]
# x11:[0.12011291 0.43229101 0.22298179 0.22461429]
# x12:[0.21953095 0.23344342 0.42168381 0.12534181]
# x13:[0.13004954 0.41233558 0.24285717 0.21475772]
# x14:[0.21055101 0.25133031 0.40383295 0.13428573]
# x15:[0.13809864 0.39622074 0.25895579 0.20672483]
# x16:[0.20329933 0.26581888 0.38935168 0.14153011]
# x17:[0.1446185  0.38317765 0.27199559 0.20020826]
# x18:[0.19742994 0.27755467 0.37761737 0.14739802]
# x19:[0.1498996  0.37261477 0.28255781 0.19492782]
# x20:[0.19267665 0.28706066 0.36811168 0.15215102]
# x21:[0.1541773  0.36405924 0.29111321 0.19065026]
# x22:[0.18882666 0.29476051 0.36041189 0.15600094]
# x23:[0.15764223 0.35712934 0.29804308 0.18718535]
# x24:[0.1857082  0.30099739 0.35417502 0.15911939]
# x25:[0.16044883 0.35151614 0.30365627 0.18437876]
# x26:[0.18318226 0.30604927 0.34912315 0.16164532]
# x27:[0.16272217 0.34696945 0.30820296 0.18210542]
# x28:[0.18113625 0.31014129 0.34503113 0.16369133]
# x29:[0.16456358 0.34328664 0.31188578 0.18026401]
# x30:[0.17947899 0.31345582 0.34171659 0.1653486 ]
# x31:[0.16605512 0.34030355 0.31486886 0.17877247]
# x32:[0.1781366  0.31614059 0.33903182 0.16669099]
# x33:[0.16726327 0.33788726 0.31728516 0.17756432]
# x34:[0.17704927 0.31831526 0.33685715 0.16777832]
# x35:[0.16824187 0.33593006 0.31924236 0.17658572]
# x36:[0.17616853 0.32007674 0.33509567 0.16865906]
# x37:[0.16903453 0.33434473 0.32082769 0.17579305]
# x38:[0.17545513 0.32150354 0.33366887 0.16937246]
# x39:[0.16967659 0.33306061 0.32211181 0.17515099]
# x40:[0.17487727 0.32265925 0.33251317 0.16995031]
# x41:[0.17019666 0.33202047 0.32315194 0.17463093]
# x42:[0.17440921 0.32359537 0.33157705 0.17041837]
# x139:[0.17241372 0.32758635 0.32758606 0.17241387]
# x140:[0.17241386 0.32758608 0.32758634 0.17241373]
# x141:[0.17241373 0.32758632 0.32758609 0.17241385]
# x142:[0.17241385 0.3275861  0.32758631 0.17241374]
# x143:[0.17241375 0.3275863  0.32758611 0.17241384]
# x144:[0.17241384 0.32758612 0.32758629 0.17241375]
# x145:[0.17241375 0.32758628 0.32758613 0.17241383]
# x146:[0.17241383 0.32758614 0.32758628 0.17241376]
# x147:[0.17241376 0.32758627 0.32758614 0.17241382]
# x148:[0.17241382 0.32758615 0.32758626 0.17241376]
# x149:[0.17241377 0.32758626 0.32758616 0.17241382]
# x150:[0.17241382 0.32758616 0.32758625 0.17241377]
# x151:[0.17241377 0.32758625 0.32758617 0.17241381]
# x152:[0.17241381 0.32758617 0.32758624 0.17241377]
# x153:[0.17241378 0.32758624 0.32758617 0.17241381]
# x154:[0.17241381 0.32758618 0.32758624 0.17241378]
# x155:[0.17241378 0.32758623 0.32758618 0.17241381]
# x156:[0.17241381 0.32758618 0.32758623 0.17241378]
# x157:[0.17241378 0.32758623 0.32758619 0.1724138 ]
# x158:[0.1724138  0.32758619 0.32758623 0.17241378]
# x159:[0.17241378 0.32758622 0.32758619 0.1724138 ]
# x160:[0.1724138  0.32758619 0.32758622 0.17241379]
# x161:[0.17241379 0.32758622 0.32758619 0.1724138 ]
# x162:[0.1724138  0.32758619 0.32758622 0.17241379]
# x163:[0.17241379 0.32758622 0.3275862  0.1724138 ]
# x164:[0.1724138  0.3275862  0.32758622 0.17241379]
# x165:[0.17241379 0.32758622 0.3275862  0.1724138 ]
# x166:[0.1724138  0.3275862  0.32758622 0.17241379]
# x167:[0.17241379 0.32758621 0.3275862  0.1724138 ]
# x168:[0.1724138  0.3275862  0.32758621 0.17241379]
# x169:[0.17241379 0.32758621 0.3275862  0.1724138 ]
# x170:[0.1724138  0.3275862  0.32758621 0.17241379]
# x171:[0.17241379 0.32758621 0.3275862  0.1724138 ]
# x172:[0.1724138  0.3275862  0.32758621 0.17241379]
# x173:[0.17241379 0.32758621 0.3275862  0.1724138 ]
# x174:[0.17241379 0.3275862  0.32758621 0.17241379]
# x175:[0.17241379 0.32758621 0.3275862  0.17241379]
# x176:[0.17241379 0.3275862  0.32758621 0.17241379]
# x177:[0.17241379 0.32758621 0.3275862  0.17241379]
# x178:[0.17241379 0.3275862  0.32758621 0.17241379]
# x179:[0.17241379 0.32758621 0.3275862  0.17241379]
# x180:[0.17241379 0.3275862  0.32758621 0.17241379]
# x181:[0.17241379 0.32758621 0.32758621 0.17241379]
# Converged steady state vector :
# array([0.17241379, 0.32758621, 0.32758621, 0.17241379])

# %%
# Ranking the web pages 
print("Web pages according to rank (largest to smallest) : ")
list((-final_prob_vect).argsort()[:N])
# Out:
# Web pages according to rank (largest to smallest) :
# [2, 1, 0, 3]
